# %% [markdown]
# <a href="https://colab.research.google.com/github/E-E-JUN/Storage2/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("하늘을 나는 김대원")
# Out:
# 하늘을 나는 김대원
